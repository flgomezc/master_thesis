# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D

# %%
# !wget https://github.com/forero/abacus/raw/master/data/AbacusCosmos_1100box_00_FoF_halos_z0.300/cuts/sphere_data_cut_0.dat
# Out:
# --2019-02-13 18:10:31--  https://github.com/forero/abacus/raw/master/data/AbacusCosmos_1100box_00_FoF_halos_z0.300/cuts/sphere_data_cut_0.dat
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/forero/abacus/master/data/AbacusCosmos_1100box_00_FoF_halos_z0.300/cuts/sphere_data_cut_0.dat [following]
# --2019-02-13 18:10:32--  https://raw.githubusercontent.com/forero/abacus/master/data/AbacusCosmos_1100box_00_FoF_halos_z0.300/cuts/sphere_data_cut_0.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.4.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.4.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 779142 (761K) [text/plain]
# Saving to: ‘sphere_data_cut_0.dat.1’
#
# sphere_data_cut_0.d 100%[===================>] 760,88K   764KB/s    in 1,0s
#
# 2019-02-13 18:10:33 (764 KB/s) - ‘sphere_data_cut_0.dat.1’ saved [779142/779142]

# %%
seed = 20190213
np.random.seed(seed)
Radius = 100
VOID_TYPE = "REAL"
N = 20000     ################ The double!!!   N_rc = 2 * N_oc

# %%
def sph_random_point():
    u = np.random.rand()
    x1 = np.random.normal()
    x2 = np.random.normal()
    x3 = np.random.normal()
    
    norm = np.sqrt( x1**2 + x2**2 + x3**2)
    x1 /= norm
    x2 /= norm
    x3 /= norm
    
    r = Radius * u ** (1/3)
    
    return  [r*x1,r*x2,r*x3]

# %%
RC = np.zeros([N,3])
for x in RC:
    x += sph_random_point()
np.savetxt("rnd_sph_cat_R100_seed20190213.cat", RC)


OC = np.loadtxt("./sphere_data_cut_0.dat")
OC = OC + 400


FC = np.vstack([RC,OC])
np.savetxt("FC_N{}_{}.cat".format(N,VOID_TYPE), FC)

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect('equal')


X = OC[:,0]
Y = OC[:,1]
Z = OC[:,2]

ax.scatter(X, Y, Z, c="blue", s=0.1, label="Abacus Dataset")

X = RC[:,0]
Y = RC[:,1]
Z = RC[:,2]

#ax.scatter(X, Y, Z, c="red", s=0.1)


plt.title("LSS from Abacus")

plt.savefig("lss_abacus_dataset.pdf")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# !make NPARTICLES=$N VOID_TYPE=$VOID_TYPE
# Out:
# Input File FC_N20000_REAL.cat
# cp FC_N20000_REAL.cat IXodFQcksg
#
# Calling NGL
# /home/filipo/master_thesis/ngl-beta/build/binsrc/./getNeighborGraph -i IXodFQcksg -d 3 -m BSkeleton -b 1.0c > FC_N20000_REAL_Beta1.0.bsk
# Ellapsed time: 5871.804688 s.
# Output file: FC_N20000_REAL_Beta1.0.bsk
# Deleting auxiliar file
# rm IXodFQcksg

# %%
# !ls -lt
# Out:
# total 21256
# -rw-rw-r-- 1 filipo filipo 2293399 feb 19 17:20 FC_N20000_REAL.cat
# -rw-rw-r-- 1 filipo filipo 1529835 feb 19 17:20 rnd_sph_cat_R100_seed20190213.cat
# -rw-rw-r-- 1 filipo filipo 2445965 feb 14 21:35 abacus_first_test.ipynb
# -rw-rw-r-- 1 filipo filipo 2991334 feb 14 21:33 tagging_voids.pdf
# -rw-rw-r-- 1 filipo filipo 1722350 feb 14 21:32 BS_of_Voids.bsk
# -rw-rw-r-- 1 filipo filipo   30593 feb 14 21:32 slice_OC_RC_VP_90.0.pdf
# -rw-rw-r-- 1 filipo filipo   59906 feb 14 21:32 slice_OC_RC_VP_67.5.pdf
# -rw-rw-r-- 1 filipo filipo   80011 feb 14 21:32 slice_OC_RC_VP_45.0.pdf
# -rw-rw-r-- 1 filipo filipo   93088 feb 14 21:32 slice_OC_RC_VP_22.5.pdf
# -rw-rw-r-- 1 filipo filipo   96461 feb 14 21:32 slice_OC_RC_VP_0.0.pdf
# -rw-rw-r-- 1 filipo filipo   90629 feb 14 21:32 slice_OC_RC_VP_-22.5.pdf
# -rw-rw-r-- 1 filipo filipo   83127 feb 14 21:32 slice_OC_RC_VP_-45.0.pdf
# -rw-rw-r-- 1 filipo filipo   59861 feb 14 21:32 slice_OC_RC_VP_-67.5.pdf
# -rw-rw-r-- 1 filipo filipo   29856 feb 14 21:32 slice_OC_RC_VP_-90.0.pdf
# -rw-rw-r-- 1 filipo filipo 2272270 feb 14 21:30 lss_abacus_dataset.pdf
# -rw-rw-r-- 1 filipo filipo 2474342 feb 13 19:50 FC_N20000_REAL_Beta1.0.bsk
# -rw-rw-r-- 1 filipo filipo  779142 feb 13 18:10 sphere_data_cut_0.dat.1
# -rw-rw-r-- 1 filipo filipo 1503738 feb 13 14:25 FC_N10000_REAL_Beta1.0.bsk
# -rw-rw-r-- 1 filipo filipo 1528490 feb 13 13:44 FC_N10000_REAL.cat
# -rw-rw-r-- 1 filipo filipo     762 feb 13 13:36 Makefile
# -rw-rw-r-- 1 filipo filipo     751 feb 13 13:35 Makefile~
# -rw-rw-r-- 1 filipo filipo  764926 feb 13 13:30 rnd_sph_cat_R100.cat
# -rw-rw-r-- 1 filipo filipo  779142 feb 13 11:41 sphere_data_cut_0.dat

# %% [markdown]
# # Loading the Full Catalog Beta-Skeleton graph

# %%
fcBSkel = np.loadtxt("FC_N20000_REAL_Beta1.0.bsk")
fcBSkel.shape
# Out:
# (220448, 2)

# %%
index = np.where(fcBSkel[:,0] < N)

first_filter = np.array(fcBSkel[index]).astype(int)

# %%
print(N)

index = np.where( first_filter[:,1] >= N )[0]

droplist_raw = first_filter[index,0]
droplist = set(droplist_raw)

print( "First filter shape:", first_filter.shape, 
      "\nHow many of them have direct connections with galaxies", len(droplist) )
# Out:
# 20000
# First filter shape: (154505, 2)
# How many of them have direct connections with galaxies 15081

# %%
rndmcat_index = set(range(N))

candidates = rndmcat_index.difference(droplist)
candidates = list(candidates)
void_cat = FC[candidates]

# %%
for k in np.linspace(-90,90,9):
    slice_height = 10
    BoxCenter = k

    fig = plt.figure(figsize=[8,8])

    index = np.where( abs(OC[:,2] - BoxCenter) < slice_height )        
    plt.scatter(OC[index,0], OC[index,1], s=2, label="Observed Catalog")

    index = np.where( abs(RC[:,2] - BoxCenter) < slice_height )        
    plt.scatter(RC[index,0], RC[index,1], s=1, label="Random Catalog")

    index = np.where( abs(void_cat[:,2] - BoxCenter) < slice_height )        
    plt.scatter(void_cat[index,0], void_cat[index,1], s=10, label="Identified As Void")

    plt.legend(loc=1)
    
    plt.savefig("slice_OC_RC_VP_{}.pdf".format(BoxCenter))
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %%
x = void_cat[:,0]
y = void_cat[:,1]
z = void_cat[:,2]

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect('equal')

ax.scatter(x, y, z, s=1)
ax.view_init(30, 30)

plt.title(VOID_TYPE +" Recognition" + "\nUsing RandomPoints & 1-Skeleton")
plt.tight_layout()

#plt.close()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
index=[]

for k in candidates:
    index.extend( list( np.where( fcBSkel[:,0] == k)[0].astype(int) ) )

index = list(set(index ) )
index.sort()

# Beta-Skeleton of Voids
VoidsBS = np.array(fcBSkel[index]).astype(int)
print(VoidsBS.shape)
print(len(candidates))
# Out:
# (34447, 2)
# 4919

# %%
np.savetxt("BS_of_Voids.bsk", VoidsBS)

# %%
candidates.sort()

# %%
MasterList = []

for search in candidates:
    
    is_in_master = any( search in sublist for sublist in MasterList)

    #print ( "Is", search, "in MasterList?", is_in_master)
    
    # If is the first time it appears on the MasterList
    if not is_in_master:
        my_list = []

        index = np.where(VoidsBS[:,0] == search)
        my_list.append(search)
        my_list.extend( list(VoidsBS[index,1][0]) )
        my_list.sort()
        MasterList.append(my_list)

    if is_in_master:
        repetitions = []
        
        for k in range(len(MasterList)):
            if(search in MasterList[k]):
                sublist = MasterList[k]
                #print("Si está en la sublista", k, sublist)
                repetitions.append(k)
                
        #print(search, "appears in sublists:" , repetitions)
        

        if ( len(repetitions) == 1 ):
            j = repetitions[0]
            index = np.where(VoidsBS[:,0] == search)
 
            #print("Index:", index)
            my_list = list(VoidsBS[index,1][0])
            my_list.sort()
            MasterList[j].extend(my_list)
        
        elif (len(repetitions) > 1):
            # print("Friend of many friends, n=", len(repetitions))
            my_list = []
            for j in repetitions:
                my_list.extend(MasterList[j])
                MasterList[j]=[]
            my_list.sort()
            MasterList.append(my_list)
            
while( [] in MasterList):
    MasterList.remove([])

# %%
for j in range(len(MasterList)):
    MasterList[j] = list( set(MasterList[j]))
    MasterList[j].sort()

# %%
to_merge = []

for i in range(len(MasterList)):
    for j in range(len(MasterList)):
        if (j > i):
            aux = [x for x in MasterList[i] if x in MasterList[j]]
            if (len(aux)>0):
                # print( i, j, aux)
                to_merge.append([i,j])

# %%
to_merge2 = []
for i in range( len(to_merge)):
    x = to_merge[i][0]
    y = to_merge[i][1]
    
    is_in_list1 = any( x in sublist for sublist in to_merge2 )
    is_in_list2 = any( y in sublist for sublist in to_merge2 )
    
    if( (is_in_list1 == False) & (is_in_list2 == False) ):
        to_merge2.append(to_merge[i])
    
    elif( (is_in_list1 == False) & (is_in_list2 == True) ):
            aux = []
            for j in range(len(to_merge2)):
                if( y in to_merge2[j]):
                    to_merge2[j].append(x)

    elif( (is_in_list1 == True) & (is_in_list2 == False) ):
            aux = []
            for j in range(len(to_merge2)):
                if( x in to_merge2[j]):
                    to_merge2[j].append(y)

    
for x in to_merge2:
    x.sort()
    
print( to_merge2)
# Out:
# [[1, 12, 107, 156, 192, 209, 212, 268, 388, 424, 463, 489, 509], [2, 166, 181, 371, 412, 447, 511], [3, 158, 276, 358, 385, 408, 425, 436], [4, 7, 51, 260, 264, 471, 510, 524], [5, 201, 516], [6, 52, 54, 59, 66, 68, 71, 83, 125, 145, 152, 184, 195, 218, 258, 272, 274, 281, 288, 289, 310, 330, 334, 345, 352, 361, 365, 370, 377, 381, 406, 413, 434, 442, 454, 493, 500, 501, 521], [8, 20, 297, 301, 306], [10, 86, 228, 390, 449, 458, 470, 505, 520], [11, 438], [13, 25, 44, 65, 70, 77, 101, 170, 180, 185, 203, 225, 239, 240, 242, 270, 280, 338, 350, 353, 394, 459, 462, 488, 491, 492, 495, 506, 517], [14, 99, 117, 135, 279, 383, 389, 419], [15, 300, 378], [16, 322, 440], [17, 48], [18, 251, 379], [19, 31, 37, 45, 115, 119, 138, 139, 197, 199, 221, 227, 271, 312, 331, 354, 398, 404, 421, 453, 464, 487, 519], [21, 123, 515], [22, 174, 217, 220], [23, 32, 113, 160, 161, 173, 222, 482, 522], [24, 215, 234, 395, 525], [26, 42, 81, 172, 448], [27, 43, 111, 144, 238], [28, 405], [29, 93], [30, 176], [33, 73, 237, 290, 446], [34, 167, 235, 296, 367, 431], [35, 63], [36, 39, 58, 74, 94, 146, 202, 207, 211, 247, 283, 316, 324, 362, 512, 527], [40, 56, 100, 286, 328], [41, 126, 153], [46, 110], [47, 95], [49, 193], [50, 246, 309], [55, 91, 298, 363], [62, 149, 219, 273, 426, 508], [67, 403, 507], [69, 257, 277, 336], [72, 456], [75, 109], [76, 85, 387], [78, 259], [80, 317], [82, 311], [84, 216], [88, 275], [89, 401, 420], [90, 183, 223, 410, 473], [92, 243, 254, 335, 369, 396, 411, 479, 499], [97, 155, 299, 318], [98, 321], [102, 233], [103, 159, 437], [104, 226, 347], [105, 231, 380, 445, 513], [108, 366], [112, 340, 376, 432], [114, 343], [116, 124, 466, 468, 518], [118, 341], [121, 162, 253, 407, 498], [122, 198, 373, 480], [127, 143, 179, 267, 284, 465], [129, 208, 364, 497], [130, 132, 141, 196, 443], [131, 384], [133, 397, 490], [134, 319], [136, 476], [137, 313], [140, 200, 418], [142, 326, 523], [148, 256, 409], [150, 486], [151, 194], [154, 178, 291, 399, 483], [157, 188, 303, 314], [163, 232, 250, 302, 382, 422], [164, 168, 255, 400, 429, 485], [169, 224, 265, 444, 467], [171, 206, 344, 372], [175, 229, 348, 528], [187, 305, 457, 526], [191, 359], [204, 342], [213, 236, 402], [214, 285], [230, 346], [241, 245], [262, 307], [263, 451], [269, 320, 417], [304, 333, 450], [308, 475], [329, 360, 439, 472], [339, 481], [349, 427], [351, 435, 452], [368, 415], [375, 392], [393, 441], [416, 502], [428, 514], [460, 478, 504]]

# %%
for sublist in to_merge2:
    aux = []
    for x in sublist:
        aux.extend(MasterList[x])
        MasterList[x] = []
    aux.sort()
    MasterList.append(aux)
    
while( [] in MasterList):
    MasterList.remove([])
    

colors = cm.rainbow( np.linspace(0,1, len(MasterList)))

# %%
x = RC[:,0]
y = RC[:,1]
z = RC[:,2]

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect('equal')

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

for k in range(len(MasterList)): 
    void = MasterList[k]
    ax.scatter(x[void], y[void], z[void], s=0.5, c=colors[k])

ax.view_init(15, 30)

plt.title("Void Tagging\nUsing RandomPoints & 1-Skeleton")
plt.tight_layout()


plt.savefig("./tagging_voids.pdf", format="pdf")
#plt.close()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
print("Total number of Void Particles", len(candidates))

aux = 0
for halo in MasterList:
    # print( len(halo))
    aux += len(halo)

print("Total number of particles in halos:", aux , "(Void + Frontier particles)")
# Out:
# Total number of Void Particles 4919
# Total number of particles in halos: 14541 (Void + Frontier particles)

# %%
X = RC[:,0]
Y = RC[:,1]
Z = RC[:,2]

with open("void_masterlist_N20000.cat", 'w') as file:
    
    for halo in MasterList:   
        for particle in halo:
            line  = str(MasterList.index(halo)) + ", " 
            line += str(X[particle]) + ", " 
            line += str(Y[particle]) + ", " 
            line += str(Z[particle] ) + "\n"

            file.write(line)
