# %%
import numpy as np
import matplotlib.pyplot as plt
import subprocess as subp
import os
import timeit

TESTING = True

# %%
### Paths
RC_path = "random_catalogs/"
FC_path = "full_catalogs/"
OC_path = "observed_catalogs/"
BS_path = "xdl_beta_skeleton/"
ML_path = "masterlists/"

### Create VolumeAndExcentricity directory
VE_path = "volume_and_excentricity/"
subp.run("mkdir -p " + VE_path, shell=True, check=True)

### 
List_Random_Catalogs   = os.listdir(RC_path)
List_Full_Catalogs     = os.listdir(FC_path)
List_Observed_Catalogs = os.listdir(OC_path)
List_BetaSkeleton      = os.listdir(BS_path)
List_MasterLists       = os.listdir(ML_path)

List_Random_Catalogs.sort()
List_Full_Catalogs.sort()
List_Observed_Catalogs.sort()
List_BetaSkeleton.sort()
List_MasterLists.sort()

# Create the n_rand and beta list.

n_rand = []
beta   = []

for l in List_Random_Catalogs:
    n_rand.append( l.split("_")[8] )
    beta.append(l.split("_")[10])

if (TESTING == True):
    Times = 8
else:
    Times = len(List_Random_Catalogs)

# Some constants:
cut = List_Random_Catalogs[0].split("_")[6]


#################################################################
#                                                               #
#                    Void Finder Main Loop                      #
#                                                               #
#################################################################
subp.run( "echo # Count, Beta, n_rand > 04_Excentricity_progress.txt", shell=True, check=True)

# debug
# for maxiCounter in range(Times):
for maxiCounter in range(0, Times):
    # debug
    #maxiCounter = 1

    toc = timeit.default_timer()
    #maxiCounter = 0

    InitialMessage  = "\n\n ########################"
    InitialMessage += "\n Running with:\n"
    InitialMessage += "\n\t n_rand = {}".format(n_rand[maxiCounter])
    InitialMessage += "\n\t beta   = {}".format(beta[maxiCounter])
    InitialMessage += "\n"

    print(InitialMessage)


    RC_filename = List_Random_Catalogs[maxiCounter]
    FC_filename = List_Full_Catalogs[maxiCounter]
    BS_filename = List_BetaSkeleton[maxiCounter]
    OC_filename = List_Observed_Catalogs[0]
    ML_filename = List_MasterLists[maxiCounter]

    print(ML_filename)
    
    
    RC = np.loadtxt(RC_path + RC_filename)
    N_rnd = RC.shape[0]

    OC = np.loadtxt(OC_path + OC_filename)
    N_obs = OC.shape[0]
    
    ##### RE-CENERING!!!!  ############################################# Hey! To Do Centering
    for x in OC:
        x += np.array([400,400,400])
    # The centering has been done.
    ######################################################################
    
    
    FC = np.loadtxt(FC_path + FC_filename)
    BS = np.loadtxt(BS_path + BS_filename)

    print("Previous BetaSkeleton Shape before Stacking: ", BS.shape)

    ### Transforms Xiao-Dong Li's Beta Skeleton Index to long list
    a = BS[:,0].astype(int)
    a = list(a)
    b = BS[:,1].astype(int)
    b = list(b)

    c = []
    c.extend(a)
    c.extend(b)
    d = []
    d.extend(b)
    d.extend(a)

    c = np.array(c, dtype=int)
    d = np.array(d, dtype=int)

    fcBSkel = np.vstack((c,d)).T
    a = b = c = d = 0
    print("Next BetaSkeleton Shape after Stacking: ", fcBSkel.shape)

    print("Loading MasterList into 'Void Particle Cat'")
    VoidParticleCat = np.loadtxt(ML_path + ML_filename)
    print("Void Particle Cat")
    print("VoidID, x, y, z")
    print("Shape", VoidParticleCat.shape)
    
    # debug
    # print(VoidParticleCat)
    
    Void_N_particles_list = VoidParticleCat[:,0].astype(int)
    print("Len Void_N_particles_list", len(Void_N_particles_list)) 

    # debug
    # print(Void_N_particles_list)
    
    # Void ID, Particles in this void.
    Void_N_Particles = []
    
    print("len Void_N_Particles", len(Void_N_Particles))

    M = Void_N_particles_list.max()
    
    if M > 0:
        print("\n\tNormal operation: Beta Skeleton file seems OK.")
    
        for i in range( Void_N_particles_list.max()):
            index = np.where(Void_N_particles_list == i)[0]
            Void_N_Particles.append([i, index.shape[0]])

        Void_N_Particles = np.array(Void_N_Particles).astype("int")

        print("Void number of Particles", Void_N_Particles.shape)

        
        
    
        plt.scatter( Void_N_Particles[:,0], Void_N_Particles[:,1])
        plt.yscale("log")

        plt.ylabel("Particles per Void")
        plt.xlabel("Void ID")

        plt.show()

        VE_filename = "VolumeAndEcentricity_cut_{}_nrand_{}_Beta_{}_.vae".format(cut,
                                                                            n_rand[maxiCounter],
                                                                            beta[maxiCounter])





        #################################################################
        #                                                               #
        #                   Calcule and Store                           #
        #               Volume and Excentricity                         #
        #                                                               #
        #################################################################

        with open(VE_path + VE_filename, "w") as file:
            file.write("# Void_ID, Void_Volume, r = (a*b*c)**(1/3.0), a, b, c, vector_a, vector_b, vector_c \n\n")

            for ID in Void_N_Particles[:,0]:
                #print(ID)
                #PlotVoidInCatalog(ID, 10)

                index = np.where( VoidParticleCat[:,0] == ID)[0]
                Void_n = VoidParticleCat[index, 1:4]
                particles_void_N = Void_n.shape[0]

                # Avoid 2 and three particle Voids
                if particles_void_N > 4:
                    ###########################################
                    #       Move to center of mass
                    #           frame of reference.
                    x = Void_n[:,0]
                    y = Void_n[:,1]
                    z = Void_n[:,2]

                    x_c = x.mean()
                    y_c = y.mean()
                    z_c = z.mean()

                    x -= x.mean()
                    y -= y.mean()
                    z -= z.mean()
                    #
                    ###########################################


                    ##########################################
                    #        Calcule Inertia Tensor
                    #              for Void Particles.
                    I_11 = 0
                    I_22 = 0
                    I_33 = 0

                    I_12 = 0
                    I_13 = 0
                    I_23 = 0

                    for k in range( particles_void_N ):
                        I_11 += y[k]**2 + z[k]**2
                        I_22 += z[k]**2 + x[k]**2
                        I_33 += x[k]**2 + y[k]**2

                        I_12 += - x[k] * y[k]
                        I_13 += - z[k] * x[k]
                        I_23 += - y[k] * z[k]

                    I_21 = I_12
                    I_31 = I_13
                    I_32 = I_23

                    I = np.array([
                        [I_11, I_12, I_13],
                        [I_21, I_22, I_23],
                        [I_31, I_32, I_33]])

                    I = I/particles_void_N  # mass = \sum_1^N 1 / N = 1
                    #
                    ###################################################


                    ###################################################
                    #   Eigenvalues (w[i])
                    #          and
                    #   EigenVector  (v[i])
                    #
                    w, v = np.linalg.eig(I)


                    w_max_index = np.where(w == w.max())[0]
                    w_min_index = np.where(w == w.min())[0]
                    w_med_index = np.where( (w != w.max()) & (w != w.min()))[0]


                    # Sort semiaxes by length.
                    # a - major semi-axis
                    # b - med. semi-axis
                    # c - minor semi-axis

                    I_a = w[ w_min_index[0] ]
                    I_b = w[ w_med_index[0] ]
                    I_c = w[ w_max_index[0] ]

                    a = ((5.0/2.0)*( -I_a + I_b + I_c))**0.5
                    b = ((5.0/2.0)*( +I_a - I_b + I_c))**0.5
                    c = ((5.0/2.0)*( +I_a + I_b - I_c))**0.5

                    axis_a = v[:, w_min_index]
                    axis_b = v[:, w_med_index]
                    axis_c = v[:, w_max_index]
                    #
                    ##################################################

                    vectors = [axis_a, axis_b, axis_c]

                    str_vectors = ""

                    for i in range(3):
                        for j in range(3):
                            str_vectors += str(vectors[i][j][0]) + ", "

                    V = (4.0 / 3.0) * np.pi * a * b * c   
                    r = (a*b*c)**(1/3.0)

                    # debug
                    # print(r, V)
                    stats = "{}, {}, {}, {}, {}, {}, {} \n".format(ID, V, r, a, b, c, str_vectors)
                    file.write(stats)
    else:
        print("\n\n\t%%%%%%%%%%%%%%%%%%%%%%%%%%")
        print("\n  \t% Beta Skeleton Failure  %")
        print("\n  \t%%%%%%%%%%%%%%%%%%%%%%%%%%")
        
        
    tic = timeit.default_timer()

    FinalMessage = "\n We have fihished the process of "
    FinalMessage += "\n Finding Voids excentricity and Volume in the file with "
    FinalMessage += "\n Step {} of {}".format(maxiCounter+1, Times)
    FinalMessage += "\n beta: \t{}".format(beta[maxiCounter])
    FinalMessage += "\n n_rnd:\t{}".format(n_rand[maxiCounter])
    FinalMessage += "\n\n\tOutput written in \n" + VE_path + VE_filename
    FinalMessage += "\n\n\t Time elapsed:{} seconds".format(tic - toc)
    FinalMessage += "\n\n ########################"

    print(FinalMessage)


    subp.run( "echo {}, {}, {}, {} >> 04_Excentricity_progress.txt".format(maxiCounter, beta[maxiCounter], n_rand[maxiCounter], tic-toc), shell=True, check=True)
# Out:
#  ########################
#  Running with:
#
# 	 n_rand = 1.0003942825933594
# 	 beta   = 2.7247057781074484
#
# VoidMasterList_cut_0_nrand_1.0003942825933594_Beta_2.7247057781074484_.vml
# Previous BetaSkeleton Shape before Stacking:  (21195, 2)
# Next BetaSkeleton Shape after Stacking:  (42390, 2)
# Loading MasterList into 'Void Particle Cat'
# Void Particle Cat
# VoidID, x, y, z
# Shape (5718, 4)
# Len Void_N_particles_list 5718
# len Void_N_Particles 0
#
# 	Normal operation: Beta Skeleton file seems OK.
# Void number of Particles (1083, 2)
#  We have fihished the process of
#  Finding Voids excentricity and Volume in the file with
#  Step 1 of 8
#  beta: 	2.7247057781074484
#  n_rnd:	1.0003942825933594
#
# 	Output written in
# volume_and_excentricity/VolumeAndEcentricity_cut_0_nrand_1.0003942825933594_Beta_2.7247057781074484_.vae
#
# 	 Time elapsed:1.6417879440014076 seconds
#
#  ########################
#
#
#  ########################
#  Running with:
#
# 	 n_rand = 1.005292610418878
# 	 beta   = 4.882327832814641
#
# VoidMasterList_cut_0_nrand_1.005292610418878_Beta_4.882327832814641_.vml
# Previous BetaSkeleton Shape before Stacking:  (12280, 2)
# Next BetaSkeleton Shape after Stacking:  (24560, 2)
# Loading MasterList into 'Void Particle Cat'
# Void Particle Cat
# VoidID, x, y, z
# Shape (184, 4)
# Len Void_N_particles_list 184
# len Void_N_Particles 0
#
#
# 	%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#   	% Beta Skeleton Failure  %
#
#   	%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#  We have fihished the process of
#  Finding Voids excentricity and Volume in the file with
#  Step 2 of 8
#  beta: 	4.882327832814641
#  n_rnd:	1.005292610418878
#
# 	Output written in
# volume_and_excentricity/VolumeAndEcentricity_cut_0_nrand_1.0003942825933594_Beta_2.7247057781074484_.vae
#
# 	 Time elapsed:0.8981701410011738 seconds
#
#  ########################
#
#
#  ########################
#  Running with:
#
# 	 n_rand = 1.010745274019615
# 	 beta   = 2.38322849044483
#
# VoidMasterList_cut_0_nrand_1.010745274019615_Beta_2.38322849044483_.vml
# Previous BetaSkeleton Shape before Stacking:  (24583, 2)
# Next BetaSkeleton Shape after Stacking:  (49166, 2)
# Loading MasterList into 'Void Particle Cat'
# Void Particle Cat
# VoidID, x, y, z
# Shape (5461, 4)
# Len Void_N_particles_list 5461
# len Void_N_Particles 0
#
# 	Normal operation: Beta Skeleton file seems OK.
# Void number of Particles (1779, 2)
#  We have fihished the process of
#  Finding Voids excentricity and Volume in the file with
#  Step 3 of 8
#  beta: 	2.38322849044483
#  n_rnd:	1.010745274019615
#
# 	Output written in
# volume_and_excentricity/VolumeAndEcentricity_cut_0_nrand_1.010745274019615_Beta_2.38322849044483_.vae
#
# 	 Time elapsed:1.5522753059995011 seconds
#
#  ########################
#
#
#  ########################
#  Running with:
#
# 	 n_rand = 1.011405589347782
# 	 beta   = 1.659850329671058
#
# VoidMasterList_cut_0_nrand_1.011405589347782_Beta_1.659850329671058_.vml
# Previous BetaSkeleton Shape before Stacking:  (36542, 2)
# Next BetaSkeleton Shape after Stacking:  (73084, 2)
# Loading MasterList into 'Void Particle Cat'
# Void Particle Cat
# VoidID, x, y, z
# Shape (188, 4)
# Len Void_N_particles_list 188
# len Void_N_Particles 0
#
#
# 	%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#   	% Beta Skeleton Failure  %
#
#   	%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#  We have fihished the process of
#  Finding Voids excentricity and Volume in the file with
#  Step 4 of 8
#  beta: 	1.659850329671058
#  n_rnd:	1.011405589347782
#
# 	Output written in
# volume_and_excentricity/VolumeAndEcentricity_cut_0_nrand_1.010745274019615_Beta_2.38322849044483_.vae
#
# 	 Time elapsed:0.9178044770014822 seconds
#
#  ########################
#
#
#  ########################
#  Running with:
#
# 	 n_rand = 1.013426605291278
# 	 beta   = 1.1666500814350047
#
# VoidMasterList_cut_0_nrand_1.013426605291278_Beta_1.1666500814350047_.vml
# Previous BetaSkeleton Shape before Stacking:  (56767, 2)
# Next BetaSkeleton Shape after Stacking:  (113534, 2)
# Loading MasterList into 'Void Particle Cat'
# Void Particle Cat
# VoidID, x, y, z
# Shape (5392, 4)
# Len Void_N_particles_list 5392
# len Void_N_Particles 0
#
# 	Normal operation: Beta Skeleton file seems OK.
# Void number of Particles (885, 2)
#  We have fihished the process of
#  Finding Voids excentricity and Volume in the file with
#  Step 5 of 8
#  beta: 	1.1666500814350047
#  n_rnd:	1.013426605291278
#
# 	Output written in
# volume_and_excentricity/VolumeAndEcentricity_cut_0_nrand_1.013426605291278_Beta_1.1666500814350047_.vae
#
# 	 Time elapsed:1.9022229129986954 seconds
#
#  ########################
#
#
#  ########################
#  Running with:
#
# 	 n_rand = 1.028967470936494
# 	 beta   = 2.6982471535986554
#
# VoidMasterList_cut_0_nrand_1.028967470936494_Beta_2.6982471535986554_.vml
# Previous BetaSkeleton Shape before Stacking:  (21813, 2)
# Next BetaSkeleton Shape after Stacking:  (43626, 2)
# Loading MasterList into 'Void Particle Cat'
# Void Particle Cat
# VoidID, x, y, z
# Shape (188, 4)
# Len Void_N_particles_list 188
# len Void_N_Particles 0
#
#
# 	%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#   	% Beta Skeleton Failure  %
#
#   	%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#  We have fihished the process of
#  Finding Voids excentricity and Volume in the file with
#  Step 6 of 8
#  beta: 	2.6982471535986554
#  n_rnd:	1.028967470936494
#
# 	Output written in
# volume_and_excentricity/VolumeAndEcentricity_cut_0_nrand_1.013426605291278_Beta_1.1666500814350047_.vae
#
# 	 Time elapsed:0.9062100350020046 seconds
#
#  ########################
#
#
#  ########################
#  Running with:
#
# 	 n_rand = 1.0360627965320983
# 	 beta   = 3.076342439099551
#
# VoidMasterList_cut_0_nrand_1.0360627965320983_Beta_3.076342439099551_.vml
# Previous BetaSkeleton Shape before Stacking:  (19207, 2)
# Next BetaSkeleton Shape after Stacking:  (38414, 2)
# Loading MasterList into 'Void Particle Cat'
# Void Particle Cat
# VoidID, x, y, z
# Shape (3525, 4)
# Len Void_N_particles_list 3525
# len Void_N_Particles 0
#
# 	Normal operation: Beta Skeleton file seems OK.
# Void number of Particles (384, 2)
#  We have fihished the process of
#  Finding Voids excentricity and Volume in the file with
#  Step 7 of 8
#  beta: 	3.076342439099551
#  n_rnd:	1.0360627965320983
#
# 	Output written in
# volume_and_excentricity/VolumeAndEcentricity_cut_0_nrand_1.0360627965320983_Beta_3.076342439099551_.vae
#
# 	 Time elapsed:1.451802563999081 seconds
#
#  ########################
#
#
#  ########################
#  Running with:
#
# 	 n_rand = 1.0420271369206833
# 	 beta   = 3.7302838198808788
#
# VoidMasterList_cut_0_nrand_1.0420271369206833_Beta_3.7302838198808788_.vml
# Previous BetaSkeleton Shape before Stacking:  (15951, 2)
# Next BetaSkeleton Shape after Stacking:  (31902, 2)
# Loading MasterList into 'Void Particle Cat'
# Void Particle Cat
# VoidID, x, y, z
# Shape (190, 4)
# Len Void_N_particles_list 190
# len Void_N_Particles 0
#
#
# 	%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#   	% Beta Skeleton Failure  %
#
#   	%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#  We have fihished the process of
#  Finding Voids excentricity and Volume in the file with
#  Step 8 of 8
#  beta: 	3.7302838198808788
#  n_rnd:	1.0420271369206833
#
# 	Output written in
# volume_and_excentricity/VolumeAndEcentricity_cut_0_nrand_1.0360627965320983_Beta_3.076342439099551_.vae
#
# 	 Time elapsed:0.8219890129985288 seconds
#
#  ########################
